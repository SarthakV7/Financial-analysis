# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakV7/Financial-analysis/blob/main/Stock_Market_Analysis_(Tesla_Ford_GM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Market Analysis Project
#
# ### Please Note: You are free to treat this as a full exercise, or just view the solutions video as a code along project. This project is meant to be pretty challenging as it will introduce a few new concepts through some hints!
#
# Welcome to your first capstone project! This project is meant to cap off the first half of the course, which mainly dealt with learning the libraries that we use in this course, the second half of the course will deal a lot more with quantitative trading techniques and platforms.
#
# We'll be analyzing stock data related to a few car companies, from Jan 1 2012 to Jan 1 2017. Keep in mind that this project is mainly just to practice your skills with matplotlib, pandas, and numpy. Don't infer financial trading advice from the analysis we do here!
#
# ### Part 0: Import
#
# ** Import the various libraries you will need-you can always just come back up here or import as you go along :) **

# %%
# !pip install quandl
# !pip install --upgrade plotly

# %%
import pandas_datareader.data as pdr
from datetime import datetime
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import quandl
sns.set()

# %% [markdown]
# ____
# ## Part 1: Getting the Data
#
# ### Tesla Stock (Ticker: TSLA on the NASDAQ)
#
# **  *Note! Not everyone will be working on a computer that will give them open access to download the stock information using pandas_datareader (firewalls, admin permissions, etc...). Because of this, the csv file for the Tesla is provided in a data folder inside this folder. It is called Tesla_Stock.csv. Feel free to just use this with read_csv! **
#
# ** Use pandas_datareader to obtain the historical stock information for Tesla from Jan 1, 2012 to Jan 1, 2017.**

# %%
df = quandl.get('WIKI/TSLA', start_date='2012-01-03')
# df = pdr.get_data_yahoo('TSLA', datetime(2012,1,3)) # alternative
df_tesla = df[df.columns[:5]]
df_tesla.head()
# Out:
#              Open   High    Low  Close     Volume
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928100.0
# 2012-01-04  28.21  28.67  27.50  27.71   630100.0
# 2012-01-05  27.76  27.93  26.85  27.12  1005500.0
# 2012-01-06  27.20  27.79  26.41  26.91   986300.0
# 2012-01-09  27.00  27.49  26.12  27.25   897000.0

# %%
# Out:
#              Open   High    Low  Close   Volume
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928052
# 2012-01-04  28.21  28.67  27.50  27.71   630036
# 2012-01-05  27.76  27.93  26.85  27.12  1005432
# 2012-01-06  27.20  27.79  26.41  26.89   687081
# 2012-01-09  27.00  27.49  26.12  27.25   896951

# %% [markdown]
# ### Other Car Companies
#
# ** Repeat the same steps to grab data for Ford and GM (General Motors), **

# %%
df = quandl.get('WIKI/F', start_date='2012-01-03')
df_ford = df[df.columns[:5]]
df_ford.head()
# Out:
#              Open   High    Low  Close      Volume
# Date
# 2012-01-03  11.00  11.25  10.99  11.13  45709900.0
# 2012-01-04  11.15  11.53  11.07  11.30  79725200.0
# 2012-01-05  11.33  11.63  11.24  11.59  67877500.0
# 2012-01-06  11.74  11.80  11.52  11.71  59840700.0
# 2012-01-09  11.83  11.95  11.70  11.80  53981500.0

# %%
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2012-01-03  11.00  11.25  10.99  11.13  45709811
# 2012-01-04  11.15  11.53  11.07  11.30  79725188
# 2012-01-05  11.33  11.63  11.24  11.59  67877467
# 2012-01-06  11.74  11.80  11.52  11.71  59840605
# 2012-01-09  11.83  11.95  11.70  11.80  53981467

# %%
df = quandl.get('WIKI/GM', start_date='2012-01-03')
df_gm = df[df.columns[:5]]
df_gm.head()
# Out:
#              Open   High    Low  Close      Volume
# Date
# 2012-01-03  20.83  21.18  20.75  21.05   9321300.0
# 2012-01-04  21.05  21.37  20.75  21.15   7856700.0
# 2012-01-05  21.10  22.29  20.96  22.17  17880600.0
# 2012-01-06  22.26  23.03  22.24  22.92  18234500.0
# 2012-01-09  23.20  23.43  22.70  22.84  12084500.0

# %%
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2012-01-03  20.83  21.18  20.75  21.05   9321420
# 2012-01-04  21.05  21.37  20.75  21.15   7856752
# 2012-01-05  21.10  22.29  20.96  22.17  17884040
# 2012-01-06  22.26  23.03  22.24  22.92  18234608
# 2012-01-09  23.20  23.43  22.70  22.84  12091714

# %% [markdown]
# ## Part 2: Visualizing the Data
#
# ** Time to visualize the data. **
#
# ** Follow along and recreate the plots below according to the instructions and explanations. **

# %% [markdown]
# ____
#
# ** Recreate this linear plot of all the stocks' Open price ! Hint: For the legend, use label parameter and plt.legend()**

# %%
# Code Here
# using plotly
df = pd.concat((df_tesla['Open'], df_ford['Open'], df_gm['Open']), axis=1)
df.columns = ['TSLA', 'FORD', 'GM']
fig = px.line(df, x=df.index , y=df.columns, )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="4d38136e-dd45-4665-877a-790ee35cdfc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d38136e-dd45-4665-877a-790ee35cdfc6")) {                    Plotly.newPlot(                        "4d38136e-dd45-4665-877a-790ee35cdfc6",                        [{"hovertemplate": "variable=TSLA<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "TSLA", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "TSLA", "showlegend": true, "type": "scattergl", "x": ["2012-01-03T00:00:00", "2012-01-04T00:00:00", "2012-01-05T00:00:00", "2012-01-06T00:00:00", "2012-01-09T00:00:00", "2012-01-10T00:00:00", "2012-01-11T00:00:00", "2012-01-12T00:00:00", "2012-01-13T00:00:00", "2012-01-17T00:00:00", "2012-01-18T00:00:00", "2012-01-19T00:00:00", "2012-01-20T00:00:00", "2012-01-23T00:00:00", "2012-01-24T00:00:00", "2012-01-25T00:00:00", "2012-01-26T00:00:00", "2012-01-27T00:00:00", "2012-01-30T00:00:00", "2012-01-31T00:00:00", "2012-02-01T00:00:00", "2012-02-02T00:00:00", "2012-02-03T00:00:00", "2012-02-06T00:00:00", "2012-02-07T00:00:00", "2012-02-08T00:00:00", "2012-02-09T00:00:00", "2012-02-10T00:00:00", "2012-02-13T00:00:00", "2012-02-14T00:00:00", "2012-02-15T00:00:00", "2012-02-16T00:00:00", "2012-02-17T00:00:00", "2012-02-21T00:00:00", "2012-02-22T00:00:00", "2012-02-23T00:00:00", "2012-02-24T00:00:00", "2012-02-27T00:00:00", "2012-02-28T00:00:00", "2012-02-29T00:00:00", "2012-03-01T00:00:00", "2012-03-02T00:00:00", "2012-03-05T00:00:00", "2012-03-06T00:00:00", "2012-03-07T00:00:00", "2012-03-08T00:00:00", "2012-03-09T00:00:00", "2012-03-12T00:00:00", "2012-03-13T00:00:00", "2012-03-14T00:00:00", "2012-03-15T00:00:00", "2012-03-16T00:00:00", "2012-03-19T00:00:00", "2012-03-20T00:00:00", "2012-03-21T00:00:00", "2012-03-22T00:00:00", "2012-03-23T00:00:00", "2012-03-26T00:00:00", "2012-03-27T00:00:00", "2012-03-28T00:00:00", "2012-03-29T00:00:00", "2012-03-30T00:00:00", "2012-04-02T00:00:00", "2012-04-03T00:00:00", "2012-04-04T00:00:00", "2012-04-05T00:00:00", "2012-04-09T00:00:00", "2012-04-10T00:00:00", "2012-04-11T00:00:00", "2012-04-12T00:00:00", "2012-04-13T00:00:00", "2012-04-16T00:00:00", "2012-04-17T00:00:00", "2012-04-18T00:00:00", "2012-04-19T00:00:00", "2012-04-20T00:00:00", "2012-04-23T00:00:00", "2012-04-24T00:00:00", "2012-04-25T00:00:00", "2012-04-26T00:00:00", "2012-04-27T00:00:00", "2012-04-30T00:00:00", "2012-05-01T00:00:00", "2012-05-02T00:00:00", "2012-05-03T00:00:00", "2012-05-04T00:00:00", "2012-05-07T00:00:00", "2012-05-08T00:00:00", "2012-05-09T00:00:00", "2012-05-10T00:00:00", "2012-05-11T00:00:00", "2012-05-14T00:00:00", "2012-05-15T00:00:00", "2012-05-16T00:00:00", "2012-05-17T00:00:00", "2012-05-18T00:00:00", "2012-05-21T00:00:00", "2012-05-22T00:00:00", "2012-05-23T00:00:00", "2012-05-24T00:00:00", "2012-05-25T00:00:00", "2012-05-29T00:00:00", "2012-05-30T00:00:00", "2012-05-31T00:00:00", "2012-06-01T00:00:00", "2012-06-04T00:00:00", "2012-06-05T00:00:00", "2012-06-06T00:00:00", "2012-06-07T00:00:00", "2012-06-08T00:00:00", "2012-06-11T00:00:00", "2012-06-12T00:00:00", "2012-06-13T00:00:00", "2012-06-14T00:00:00", "2012-06-15T00:00:00", "2012-06-18T00:00:00", "2012-06-19T00:00:00", "2012-06-20T00:00:00", "2012-06-21T00:00:00", "2012-06-22T00:00:00", "2012-06-25T00:00:00", "2012-06-26T00:00:00", "2012-06-27T00:00:00", "2012-06-28T00:00:00", "2012-06-29T00:00:00", "2012-07-02T00:00:00", "2012-07-03T00:00:00", "2012-07-05T00:00:00", "2012-07-06T00:00:00", "2012-07-09T00:00:00", "2012-07-10T00:00:00", "2012-07-11T00:00:00", "2012-07-12T00:00:00", "2012-07-13T00:00:00", "2012-07-16T00:00:00", "2012-07-17T00:00:00", "2012-07-18T00:00:00", "2012-07-19T00:00:00", "2012-07-20T00:00:00", "2012-07-23T00:00:00", "2012 ...

# %%
# using matplotlib.pyplot
df_tesla['Open'].plot(figsize=(16,6), label='TSLA')
df_ford['Open'].plot(label='FORD')
df_gm['Open'].plot(label='GM')
plt.legend()
plt.title('Open price')
plt.show()

# %% [markdown]
# ____

# %% [markdown]
# ** Plot the Volume of stock traded each day.**

# %%
# Code Here
# using plotly
df = pd.concat((df_tesla['Volume'], df_ford['Volume'], df_gm['Volume']), axis=1)
df.columns = ['TSLA', 'FORD', 'GM']
fig = px.line(df, x=df.index , y=df.columns, )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="aa5620e3-a51e-482c-b688-f50ef17e6672" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa5620e3-a51e-482c-b688-f50ef17e6672")) {                    Plotly.newPlot(                        "aa5620e3-a51e-482c-b688-f50ef17e6672",                        [{"hovertemplate": "variable=TSLA<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "TSLA", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "TSLA", "showlegend": true, "type": "scattergl", "x": ["2012-01-03T00:00:00", "2012-01-04T00:00:00", "2012-01-05T00:00:00", "2012-01-06T00:00:00", "2012-01-09T00:00:00", "2012-01-10T00:00:00", "2012-01-11T00:00:00", "2012-01-12T00:00:00", "2012-01-13T00:00:00", "2012-01-17T00:00:00", "2012-01-18T00:00:00", "2012-01-19T00:00:00", "2012-01-20T00:00:00", "2012-01-23T00:00:00", "2012-01-24T00:00:00", "2012-01-25T00:00:00", "2012-01-26T00:00:00", "2012-01-27T00:00:00", "2012-01-30T00:00:00", "2012-01-31T00:00:00", "2012-02-01T00:00:00", "2012-02-02T00:00:00", "2012-02-03T00:00:00", "2012-02-06T00:00:00", "2012-02-07T00:00:00", "2012-02-08T00:00:00", "2012-02-09T00:00:00", "2012-02-10T00:00:00", "2012-02-13T00:00:00", "2012-02-14T00:00:00", "2012-02-15T00:00:00", "2012-02-16T00:00:00", "2012-02-17T00:00:00", "2012-02-21T00:00:00", "2012-02-22T00:00:00", "2012-02-23T00:00:00", "2012-02-24T00:00:00", "2012-02-27T00:00:00", "2012-02-28T00:00:00", "2012-02-29T00:00:00", "2012-03-01T00:00:00", "2012-03-02T00:00:00", "2012-03-05T00:00:00", "2012-03-06T00:00:00", "2012-03-07T00:00:00", "2012-03-08T00:00:00", "2012-03-09T00:00:00", "2012-03-12T00:00:00", "2012-03-13T00:00:00", "2012-03-14T00:00:00", "2012-03-15T00:00:00", "2012-03-16T00:00:00", "2012-03-19T00:00:00", "2012-03-20T00:00:00", "2012-03-21T00:00:00", "2012-03-22T00:00:00", "2012-03-23T00:00:00", "2012-03-26T00:00:00", "2012-03-27T00:00:00", "2012-03-28T00:00:00", "2012-03-29T00:00:00", "2012-03-30T00:00:00", "2012-04-02T00:00:00", "2012-04-03T00:00:00", "2012-04-04T00:00:00", "2012-04-05T00:00:00", "2012-04-09T00:00:00", "2012-04-10T00:00:00", "2012-04-11T00:00:00", "2012-04-12T00:00:00", "2012-04-13T00:00:00", "2012-04-16T00:00:00", "2012-04-17T00:00:00", "2012-04-18T00:00:00", "2012-04-19T00:00:00", "2012-04-20T00:00:00", "2012-04-23T00:00:00", "2012-04-24T00:00:00", "2012-04-25T00:00:00", "2012-04-26T00:00:00", "2012-04-27T00:00:00", "2012-04-30T00:00:00", "2012-05-01T00:00:00", "2012-05-02T00:00:00", "2012-05-03T00:00:00", "2012-05-04T00:00:00", "2012-05-07T00:00:00", "2012-05-08T00:00:00", "2012-05-09T00:00:00", "2012-05-10T00:00:00", "2012-05-11T00:00:00", "2012-05-14T00:00:00", "2012-05-15T00:00:00", "2012-05-16T00:00:00", "2012-05-17T00:00:00", "2012-05-18T00:00:00", "2012-05-21T00:00:00", "2012-05-22T00:00:00", "2012-05-23T00:00:00", "2012-05-24T00:00:00", "2012-05-25T00:00:00", "2012-05-29T00:00:00", "2012-05-30T00:00:00", "2012-05-31T00:00:00", "2012-06-01T00:00:00", "2012-06-04T00:00:00", "2012-06-05T00:00:00", "2012-06-06T00:00:00", "2012-06-07T00:00:00", "2012-06-08T00:00:00", "2012-06-11T00:00:00", "2012-06-12T00:00:00", "2012-06-13T00:00:00", "2012-06-14T00:00:00", "2012-06-15T00:00:00", "2012-06-18T00:00:00", "2012-06-19T00:00:00", "2012-06-20T00:00:00", "2012-06-21T00:00:00", "2012-06-22T00:00:00", "2012-06-25T00:00:00", "2012-06-26T00:00:00", "2012-06-27T00:00:00", "2012-06-28T00:00:00", "2012-06-29T00:00:00", "2012-07-02T00:00:00", "2012-07-03T00:00:00", "2012-07-05T00:00:00", "2012-07-06T00:00:00", "2012-07-09T00:00:00", "2012-07-10T00:00:00", "2012-07-11T00:00:00", "2012-07-12T00:00:00", "2012-07-13T00:00:00", "2012-07-16T00:00:00", "2012-07-17T00:00:00", "2012-07-18T00:00:00", "2012-07-19T00:00:00", "2012-07-20T00:00:00", "2012-07-23T00:00:00", "2012 ...

# %%
# using matplotlib.pyplot
df_tesla['Volume'].plot(figsize=(16,6), label='TSLA')
df_ford['Volume'].plot(label='FORD')
df_gm['Volume'].plot(label='GM')
plt.legend()
plt.title('Volume')
plt.show()

# %% [markdown]
# ** Interesting, looks like Ford had a really big spike somewhere in late 2013. What was the date of this maximum trading volume for Ford?**
#
# **Bonus: What happened that day? **

# %%
df_ford.loc['2013-12-18']
# Out:
# Open      1.599000e+01
# High      1.600000e+01
# Low       1.517000e+01
# Close     1.565000e+01
# Volume    2.203630e+08
# Name: 2013-12-18 00:00:00, dtype: float64

# %% [markdown]
# ____

# %% [markdown]
# ** The Open Price Time Series Visualization makes Tesla look like its always been much more valuable as a company than GM and Ford. But to really understand this we would need to look at the total market cap of the company, not just the stock price. Unfortunately our current data doesn't have that information of total units of stock present. But what we can do as a simple calcualtion to try to represent total money traded would be to multply the Volume column by the Open price. Remember that this still isn't the actual Market Cap, its just a visual representation of the total amount of money being traded around using the time series. (e.g. 100 units of stock at \$10 each versus 100000 units of stock at $1 each)**

# %% [markdown]
# ** Create a new column for each dataframe called "Total Traded" which is the Open Price multiplied by the Volume Traded.**

# %%
# Code Here 
# using plotly
df_open = pd.concat((df_tesla['Open'], df_ford['Open'], df_gm['Open']), axis=1)
df_vol = pd.concat((df_tesla['Volume'], df_ford['Volume'], df_gm['Volume']), axis=1)
df = df_open*df_vol.values
df.columns = ['TSLA', 'FORD', 'GM']
fig = px.line(df, x=df.index , y=df.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="0b7c5e46-4437-438c-a701-06a2b6c0914e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b7c5e46-4437-438c-a701-06a2b6c0914e")) {                    Plotly.newPlot(                        "0b7c5e46-4437-438c-a701-06a2b6c0914e",                        [{"hovertemplate": "variable=TSLA<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "TSLA", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "TSLA", "showlegend": true, "type": "scattergl", "x": ["2012-01-03T00:00:00", "2012-01-04T00:00:00", "2012-01-05T00:00:00", "2012-01-06T00:00:00", "2012-01-09T00:00:00", "2012-01-10T00:00:00", "2012-01-11T00:00:00", "2012-01-12T00:00:00", "2012-01-13T00:00:00", "2012-01-17T00:00:00", "2012-01-18T00:00:00", "2012-01-19T00:00:00", "2012-01-20T00:00:00", "2012-01-23T00:00:00", "2012-01-24T00:00:00", "2012-01-25T00:00:00", "2012-01-26T00:00:00", "2012-01-27T00:00:00", "2012-01-30T00:00:00", "2012-01-31T00:00:00", "2012-02-01T00:00:00", "2012-02-02T00:00:00", "2012-02-03T00:00:00", "2012-02-06T00:00:00", "2012-02-07T00:00:00", "2012-02-08T00:00:00", "2012-02-09T00:00:00", "2012-02-10T00:00:00", "2012-02-13T00:00:00", "2012-02-14T00:00:00", "2012-02-15T00:00:00", "2012-02-16T00:00:00", "2012-02-17T00:00:00", "2012-02-21T00:00:00", "2012-02-22T00:00:00", "2012-02-23T00:00:00", "2012-02-24T00:00:00", "2012-02-27T00:00:00", "2012-02-28T00:00:00", "2012-02-29T00:00:00", "2012-03-01T00:00:00", "2012-03-02T00:00:00", "2012-03-05T00:00:00", "2012-03-06T00:00:00", "2012-03-07T00:00:00", "2012-03-08T00:00:00", "2012-03-09T00:00:00", "2012-03-12T00:00:00", "2012-03-13T00:00:00", "2012-03-14T00:00:00", "2012-03-15T00:00:00", "2012-03-16T00:00:00", "2012-03-19T00:00:00", "2012-03-20T00:00:00", "2012-03-21T00:00:00", "2012-03-22T00:00:00", "2012-03-23T00:00:00", "2012-03-26T00:00:00", "2012-03-27T00:00:00", "2012-03-28T00:00:00", "2012-03-29T00:00:00", "2012-03-30T00:00:00", "2012-04-02T00:00:00", "2012-04-03T00:00:00", "2012-04-04T00:00:00", "2012-04-05T00:00:00", "2012-04-09T00:00:00", "2012-04-10T00:00:00", "2012-04-11T00:00:00", "2012-04-12T00:00:00", "2012-04-13T00:00:00", "2012-04-16T00:00:00", "2012-04-17T00:00:00", "2012-04-18T00:00:00", "2012-04-19T00:00:00", "2012-04-20T00:00:00", "2012-04-23T00:00:00", "2012-04-24T00:00:00", "2012-04-25T00:00:00", "2012-04-26T00:00:00", "2012-04-27T00:00:00", "2012-04-30T00:00:00", "2012-05-01T00:00:00", "2012-05-02T00:00:00", "2012-05-03T00:00:00", "2012-05-04T00:00:00", "2012-05-07T00:00:00", "2012-05-08T00:00:00", "2012-05-09T00:00:00", "2012-05-10T00:00:00", "2012-05-11T00:00:00", "2012-05-14T00:00:00", "2012-05-15T00:00:00", "2012-05-16T00:00:00", "2012-05-17T00:00:00", "2012-05-18T00:00:00", "2012-05-21T00:00:00", "2012-05-22T00:00:00", "2012-05-23T00:00:00", "2012-05-24T00:00:00", "2012-05-25T00:00:00", "2012-05-29T00:00:00", "2012-05-30T00:00:00", "2012-05-31T00:00:00", "2012-06-01T00:00:00", "2012-06-04T00:00:00", "2012-06-05T00:00:00", "2012-06-06T00:00:00", "2012-06-07T00:00:00", "2012-06-08T00:00:00", "2012-06-11T00:00:00", "2012-06-12T00:00:00", "2012-06-13T00:00:00", "2012-06-14T00:00:00", "2012-06-15T00:00:00", "2012-06-18T00:00:00", "2012-06-19T00:00:00", "2012-06-20T00:00:00", "2012-06-21T00:00:00", "2012-06-22T00:00:00", "2012-06-25T00:00:00", "2012-06-26T00:00:00", "2012-06-27T00:00:00", "2012-06-28T00:00:00", "2012-06-29T00:00:00", "2012-07-02T00:00:00", "2012-07-03T00:00:00", "2012-07-05T00:00:00", "2012-07-06T00:00:00", "2012-07-09T00:00:00", "2012-07-10T00:00:00", "2012-07-11T00:00:00", "2012-07-12T00:00:00", "2012-07-13T00:00:00", "2012-07-16T00:00:00", "2012-07-17T00:00:00", "2012-07-18T00:00:00", "2012-07-19T00:00:00", "2012-07-20T00:00:00", "2012-07-23T00:00:00", "2012 ...

# %% [markdown]
# ** Plot this "Total Traded" against the time index.**

# %%
# Code here
# using matplotlib.pyplot
(df_tesla['Volume']*df_tesla['Open'].values).plot(figsize=(18,6), label='TSLA')
(df_ford['Volume']*df_ford['Open'].values).plot(label='FORD')
(df_gm['Volume']*df_gm['Open'].values).plot(label='GM')
plt.legend()
plt.title('Volume')
plt.show()

# %% [markdown]
# ** Interesting, looks like there was huge amount of money traded for Tesla somewhere in early 2014. What date was that and what happened? **

# %%
df_tesla.loc['2014-02-25']
# Out:
# Open           230.00
# High           259.20
# Low            228.45
# Close          248.00
# Volume    32681700.00
# Name: 2014-02-25 00:00:00, dtype: float64

# %%
# Out:
# Timestamp('2014-02-25 00:00:00')

# %% [markdown]
# ____

# %% [markdown]
# ** Let's practice plotting out some MA (Moving Averages). Plot out the MA50 and MA200 for GM. **

# %%
# Code here
# using plotly
df = pd.concat((df_gm['Open'], df_gm['Open'].rolling(50).mean(), df_gm['Open'].rolling(200).mean()), axis=1)
df.columns = ['Open', 'MA50', 'MA200']
fig = px.line(df, x=df.index , y=df.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="48b88fb1-af5b-46c2-8bf1-a87d7ff8709f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48b88fb1-af5b-46c2-8bf1-a87d7ff8709f")) {                    Plotly.newPlot(                        "48b88fb1-af5b-46c2-8bf1-a87d7ff8709f",                        [{"hovertemplate": "variable=Open<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Open", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Open", "showlegend": true, "type": "scattergl", "x": ["2012-01-03T00:00:00", "2012-01-04T00:00:00", "2012-01-05T00:00:00", "2012-01-06T00:00:00", "2012-01-09T00:00:00", "2012-01-10T00:00:00", "2012-01-11T00:00:00", "2012-01-12T00:00:00", "2012-01-13T00:00:00", "2012-01-17T00:00:00", "2012-01-18T00:00:00", "2012-01-19T00:00:00", "2012-01-20T00:00:00", "2012-01-23T00:00:00", "2012-01-24T00:00:00", "2012-01-25T00:00:00", "2012-01-26T00:00:00", "2012-01-27T00:00:00", "2012-01-30T00:00:00", "2012-01-31T00:00:00", "2012-02-01T00:00:00", "2012-02-02T00:00:00", "2012-02-03T00:00:00", "2012-02-06T00:00:00", "2012-02-07T00:00:00", "2012-02-08T00:00:00", "2012-02-09T00:00:00", "2012-02-10T00:00:00", "2012-02-13T00:00:00", "2012-02-14T00:00:00", "2012-02-15T00:00:00", "2012-02-16T00:00:00", "2012-02-17T00:00:00", "2012-02-21T00:00:00", "2012-02-22T00:00:00", "2012-02-23T00:00:00", "2012-02-24T00:00:00", "2012-02-27T00:00:00", "2012-02-28T00:00:00", "2012-02-29T00:00:00", "2012-03-01T00:00:00", "2012-03-02T00:00:00", "2012-03-05T00:00:00", "2012-03-06T00:00:00", "2012-03-07T00:00:00", "2012-03-08T00:00:00", "2012-03-09T00:00:00", "2012-03-12T00:00:00", "2012-03-13T00:00:00", "2012-03-14T00:00:00", "2012-03-15T00:00:00", "2012-03-16T00:00:00", "2012-03-19T00:00:00", "2012-03-20T00:00:00", "2012-03-21T00:00:00", "2012-03-22T00:00:00", "2012-03-23T00:00:00", "2012-03-26T00:00:00", "2012-03-27T00:00:00", "2012-03-28T00:00:00", "2012-03-29T00:00:00", "2012-03-30T00:00:00", "2012-04-02T00:00:00", "2012-04-03T00:00:00", "2012-04-04T00:00:00", "2012-04-05T00:00:00", "2012-04-09T00:00:00", "2012-04-10T00:00:00", "2012-04-11T00:00:00", "2012-04-12T00:00:00", "2012-04-13T00:00:00", "2012-04-16T00:00:00", "2012-04-17T00:00:00", "2012-04-18T00:00:00", "2012-04-19T00:00:00", "2012-04-20T00:00:00", "2012-04-23T00:00:00", "2012-04-24T00:00:00", "2012-04-25T00:00:00", "2012-04-26T00:00:00", "2012-04-27T00:00:00", "2012-04-30T00:00:00", "2012-05-01T00:00:00", "2012-05-02T00:00:00", "2012-05-03T00:00:00", "2012-05-04T00:00:00", "2012-05-07T00:00:00", "2012-05-08T00:00:00", "2012-05-09T00:00:00", "2012-05-10T00:00:00", "2012-05-11T00:00:00", "2012-05-14T00:00:00", "2012-05-15T00:00:00", "2012-05-16T00:00:00", "2012-05-17T00:00:00", "2012-05-18T00:00:00", "2012-05-21T00:00:00", "2012-05-22T00:00:00", "2012-05-23T00:00:00", "2012-05-24T00:00:00", "2012-05-25T00:00:00", "2012-05-29T00:00:00", "2012-05-30T00:00:00", "2012-05-31T00:00:00", "2012-06-01T00:00:00", "2012-06-04T00:00:00", "2012-06-05T00:00:00", "2012-06-06T00:00:00", "2012-06-07T00:00:00", "2012-06-08T00:00:00", "2012-06-11T00:00:00", "2012-06-12T00:00:00", "2012-06-13T00:00:00", "2012-06-14T00:00:00", "2012-06-15T00:00:00", "2012-06-18T00:00:00", "2012-06-19T00:00:00", "2012-06-20T00:00:00", "2012-06-21T00:00:00", "2012-06-22T00:00:00", "2012-06-25T00:00:00", "2012-06-26T00:00:00", "2012-06-27T00:00:00", "2012-06-28T00:00:00", "2012-06-29T00:00:00", "2012-07-02T00:00:00", "2012-07-03T00:00:00", "2012-07-05T00:00:00", "2012-07-06T00:00:00", "2012-07-09T00:00:00", "2012-07-10T00:00:00", "2012-07-11T00:00:00", "2012-07-12T00:00:00", "2012-07-13T00:00:00", "2012-07-16T00:00:00", "2012-07-17T00:00:00", "2012-07-18T00:00:00", "2012-07-19T00:00:00", "2012-07-20T00:00:00", "2012-07-23T00:00:00", "2012 ...

# %%
# Code here
# using matplotlib.pyplot
df_gm['Open'].plot(figsize=(18,6), label='Open')
df_gm['Open'].rolling(50).mean().plot(label='MA50')
df_gm['Open'].rolling(200).mean().plot(label='MA200')
plt.legend()
plt.show()

# %% [markdown]
# ______

# %% [markdown]
# ** Finally lets see if there is a relationship between these stocks, after all, they are all related to the car industry. We can see this easily through a scatter matrix plot. Import scatter_matrix from pandas.plotting and use it to create a scatter matrix plot of all the stocks'opening price. You may need to rearrange the columns into a new single dataframe. Hints and info can be found here: https://pandas.pydata.org/pandas-docs/stable/visualization.html#scatter-matrix-plot **

# %%
df = pd.concat((df_tesla['Open'], df_ford['Open'], df_gm['Open']), axis=1)
df.columns = ['TSLA', 'FORD', 'GM']
fig = px.scatter_matrix(df, dimensions=df.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="b491bc1d-6c5a-4c48-9fa8-333d495daece" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b491bc1d-6c5a-4c48-9fa8-333d495daece")) {                    Plotly.newPlot(                        "b491bc1d-6c5a-4c48-9fa8-333d495daece",                        [{"dimensions": [{"axis": {"matches": true}, "label": "TSLA", "values": [28.94, 28.21, 27.76, 27.2, 27.0, 27.44, 27.62, 28.48, 28.4, 26.62, 26.69, 27.19, 26.9, 26.81, 26.63, 27.27, 28.07, 28.5, 29.49, 29.9, 29.07, 29.72, 30.41, 31.1, 31.8, 31.6, 32.0, 32.26, 31.55, 31.74, 33.1, 33.5, 33.99, 34.87, 34.5, 33.86, 34.23, 33.41, 33.64, 33.81, 33.51, 34.4, 34.35, 33.25, 33.12, 33.11, 33.2, 34.69, 36.51, 36.0, 35.28, 34.9, 35.26, 34.98, 34.94, 34.97, 34.26, 35.59, 37.16, 37.78, 38.19, 37.52, 37.33, 36.7, 35.27, 35.1, 34.1, 33.15, 33.24, 33.77, 33.94, 33.41, 32.43, 32.09, 32.75, 33.14, 32.86, 31.82, 32.07, 32.96, 33.6, 33.27, 33.13, 33.5, 33.91, 32.2, 31.96, 32.5, 30.3, 32.97, 32.49, 31.92, 30.26, 29.58, 29.3, 28.37, 27.58, 30.1, 30.56, 31.25, 30.16, 30.01, 31.08, 30.07, 28.53, 28.03, 27.84, 28.2, 29.81, 28.86, 30.31, 29.23, 29.55, 30.18, 29.39, 29.94, 32.02, 33.5, 34.26, 32.6, 33.94, 32.05, 31.9, 31.9, 32.8, 31.35, 30.6, 30.81, 30.99, 30.94, 31.54, 31.57, 31.29, 32.97, 34.32, 35.0, 31.42, 32.72, 32.07, 31.05, 30.66, 29.92, 29.9, 28.71, 29.51, 27.54, 27.99, 26.84, 26.9, 27.55, 28.77, 29.9, 29.52, 29.31, 29.69, 30.75, 29.39, 29.53, 30.29, 30.15, 29.58, 29.01, 30.0, 30.06, 29.57, 28.4, 28.49, 28.6, 28.61, 28.52, 28.01, 28.0
85, 12.93, 12.91, 12.89, 12.52, 12.74, 12.46, 12.47, 12.38, 12.84, 12.74, 12.49, 12.27, 12.43, 12.11, 12.34, 12.28, 12.48, 12.74, 12.67, 12.23, 12.21, 12.41, 12.53, 12.57, 12.48, 12.64, 12.9, 12.86, 12.52, 12.48, 12.59, 12.48, 12.31, 12.45, 12.51, 12.35, 12.33, 12.55], "type": "candlestick", "x": ["2012-01-03T00:00:00", "2012-01-04T00:00:00", "2012-01-05T00:00:00", "2012-01-06T00:00:00", "2012-01-09T00:00:00", "2012-01-10T00:00:00", "2012-01-11T00:00:00", "2012-01-12T00:00:00", "2012-01-13T00:00:00", "2012-01-17T00:00:00", "2012-01-18T00:00:00", "2012-01-19T00:00:00", "2012-01-20T00:00:00", "2012-01-23T00:00:00", "2012-01-24T00:00:00", "2012-01-25T00:00:00", "2012-01-26T00:00:00", "2012-01-27T00:00:00", "2012-01-30T00:00:00", "2012-01-31T00:00:00", "2012-02-01T00:00:00", "2012-02-02T00:00:00", "2012-02-03T00:00:00", "2012-02-06T00:00:00", "2012-02-07T00:00:00", "2012-02-08T00:00:00", "2012-02-09T00:00:00", "2012-02-10T00:00:00", "2012-02-13T00:00:00", "2012-02-14T00:00:00", "2012-02-15T00:00:00", "2012-02-16T00:00:00", "2012-02-17T00:00:00", "2012-02-21T00:00:00", "2012-02-22T00:00:00", "2012-02-23T00:00:00", "2012-02-24T00:00:00", "2012-02-27T00:00:00", "2012-02-28T00:00:00", "2012-02-29T00:00:00", "2012-03-01T00:00:00", "2012-03-02T00:00:00", "2012-03-05T00:00:00", "2012-03-06T00:00:00", "2012-03-07T00:00:00", "2012-03-08T00:00:00", "2012-03-09T00:00:00", "2012-03-12T00:00:00", "2012-03-13T00:00:00", "2012-03-14T00:00:00", "2012-03-15T00:00:00", "2012-03-16T00:00:00", "2012-03-19T00:00:00", "2012-03-20T00:00:00", "2012-03-21T00:00:00", "2012-03-22T00:00:00", "2012-03-23T00:00:00", "2012-03-26T00:00:00", "2012-03-27T00:00:00", "2012-03-28T00:00:00", "2012-03-29T00:00:00", "2012-03-30T00:00:00"]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": ...

# %% [markdown]
# ____
# # Part 3: Basic Financial Analysis
#
# Now it is time to focus on a few key financial calculations. This will serve as your transition to the second half of the course. All you need to do is follow along with the instructions, this will mainly be an exercise in converting a mathematical equation or concept into code using python and pandas, something we will do often when working with quantiative data! If you feel very lost in this section, don't worry! Just go to the solutions lecture and treat it as a code-along lecture, use whatever style of learning works best for you!
#
# Let's begin!
# ____

# %% [markdown]
# ## Daily Percentage Change
# First we will begin by calculating the daily percentage change. Daily percentage change is defined by the following formula:

# %% [markdown]
# $ r_t = \frac{p_t}{p_{t-1}} -1$

# %% [markdown]
# This defines r_t (return at time t) as equal to the price at time t divided by the price at time t-1 (the previous day) minus 1. Basically this just informs you of your percent gain (or loss) if you bought the stock on day and then sold it the next day. While this isn't necessarily helpful for attempting to predict future values of the stock, its very helpful in analyzing the volatility of the stock. If daily returns have a wide distribution, the stock is more volatile from one day to the next. Let's calculate the percent returns and then plot them with a histogram, and decide which stock is the most stable!

# %% [markdown]
# ** Create a new column for each dataframe called returns. This column will be calculated from the Close price column. There are two ways to do this, either a simple calculation using the .shift() method that follows the formula above, or you can also use pandas' built in pct_change method. **

# %%
r = df_tesla['Close']/df_tesla['Close'].shift(1) - 1
df_tesla['returns'] = r
df_tesla.head()
# Out:
#              Open   High    Low  Close     Volume   returns
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928100.0       NaN
# 2012-01-04  28.21  28.67  27.50  27.71   630100.0 -0.013177
# 2012-01-05  27.76  27.93  26.85  27.12  1005500.0 -0.021292
# 2012-01-06  27.20  27.79  26.41  26.91   986300.0 -0.007743
# 2012-01-09  27.00  27.49  26.12  27.25   897000.0  0.012635

# %%
# Out:
#              Open   High    Low  Close   Volume  Total Traded   returns
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928052   26857824.88       NaN
# 2012-01-04  28.21  28.67  27.50  27.71   630036   17773315.56 -0.013177
# 2012-01-05  27.76  27.93  26.85  27.12  1005432   27910792.32 -0.021292
# 2012-01-06  27.20  27.79  26.41  26.89   687081   18688603.20 -0.008481
# 2012-01-09  27.00  27.49  26.12  27.25   896951   24217677.00  0.013388

# %%
r = df_gm['Close']/df_gm['Close'].shift(1) - 1
df_gm['returns'] = r
df_gm.head()
# Out:
#              Open   High    Low  Close      Volume   returns
# Date
# 2012-01-03  20.83  21.18  20.75  21.05   9321300.0       NaN
# 2012-01-04  21.05  21.37  20.75  21.15   7856700.0  0.004751
# 2012-01-05  21.10  22.29  20.96  22.17  17880600.0  0.048227
# 2012-01-06  22.26  23.03  22.24  22.92  18234500.0  0.033829
# 2012-01-09  23.20  23.43  22.70  22.84  12084500.0 -0.003490

# %%
# Out:
#              Open   High    Low  Close   Volume  Total Traded   returns
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928052   26857824.88       NaN
# 2012-01-04  28.21  28.67  27.50  27.71   630036   17773315.56 -0.013177
# 2012-01-05  27.76  27.93  26.85  27.12  1005432   27910792.32 -0.021292
# 2012-01-06  27.20  27.79  26.41  26.89   687081   18688603.20 -0.008481
# 2012-01-09  27.00  27.49  26.12  27.25   896951   24217677.00  0.013388

# %%
r = df_ford['Close']/df_ford['Close'].shift(1) - 1
df_ford['returns'] = r
df_ford.head()
# Out:
#              Open   High    Low  Close      Volume   returns
# Date
# 2012-01-03  11.00  11.25  10.99  11.13  45709900.0       NaN
# 2012-01-04  11.15  11.53  11.07  11.30  79725200.0  0.015274
# 2012-01-05  11.33  11.63  11.24  11.59  67877500.0  0.025664
# 2012-01-06  11.74  11.80  11.52  11.71  59840700.0  0.010354
# 2012-01-09  11.83  11.95  11.70  11.80  53981500.0  0.007686

# %%
# Out:
#              Open   High    Low  Close    Volume  Total Traded  mpl_time  \
# Date
# 2012-01-03  11.00  11.25  10.99  11.13  45709811  5.028079e+08       NaN
# 2012-01-04  11.15  11.53  11.07  11.30  79725188  8.889358e+08       NaN
# 2012-01-05  11.33  11.63  11.24  11.59  67877467  7.690517e+08       NaN
# 2012-01-06  11.74  11.80  11.52  11.71  59840605  7.025287e+08       NaN
# 2012-01-09  11.83  11.95  11.70  11.80  53981467  6.386008e+08       NaN
#
#              returns
# Date
# 2012-01-03       NaN
# 2012-01-04  0.015274
# 2012-01-05  0.025664
# 2012-01-06  0.010354
# 2012-01-09  0.007686

# %%
# Out:
#              Open   High    Low  Close    Volume  Total Traded  MA50  MA200  \
# Date
# 2012-01-03  20.83  21.18  20.75  21.05   9321420  1.941652e+08   NaN    NaN
# 2012-01-04  21.05  21.37  20.75  21.15   7856752  1.653846e+08   NaN    NaN
# 2012-01-05  21.10  22.29  20.96  22.17  17884040  3.773532e+08   NaN    NaN
# 2012-01-06  22.26  23.03  22.24  22.92  18234608  4.059024e+08   NaN    NaN
# 2012-01-09  23.20  23.43  22.70  22.84  12091714  2.805278e+08   NaN    NaN
#
#              returns
# Date
# 2012-01-03       NaN
# 2012-01-04  0.004751
# 2012-01-05  0.048227
# 2012-01-06  0.033829
# 2012-01-09 -0.003490

# %% [markdown]
# ** Now plot a histogram of each companies returns. Either do them separately, or stack them on top of each other. Which stock is the most "volatile"? (as judged by the variance in the daily returns we will discuss volatility in a lot more detail in future lectures.)**

# %%
fig = px.histogram(df_tesla['returns'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="8d0e6981-d093-4076-9d2d-bfc3777d4a40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d0e6981-d093-4076-9d2d-bfc3777d4a40")) {                    Plotly.newPlot(                        "8d0e6981-d093-4076-9d2d-bfc3777d4a40",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "variable=returns<br>value=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "returns", "marker": {"color": "#636efa"}, "name": "returns", "offsetgroup": "returns", "orientation": "v", "showlegend": true, "type": "histogram", "x": [null, -0.013176638176638056, -0.021291952363767574, -0.007743362831858391, 0.01263470828688229, 0.013577981651376136, 0.02208544532947143, 0.000708466170740385, -0.1932743362831859, 0.1671785870996052, 0.007894736842105177, -0.0018649757553150792, -0.005979073243647215, 0.006390977443609058, 0.024280911468061328, 0.02005835156819824, 0.03468001430103684, 0.013476157567380742, 0.008182748039549992, -0.01690902942171124, 0.01754385964912264, 0.022650439486139318, 0.02975206611570247, 0.020866773675762618, -0.0062893081761006275, 0.0104430379746836, 0.020357031005324044, -0.04542664211172487, 0.012540192926044913, 0.053350269926961014
# %%
df_tesla['returns'].hist(figsize=(18,6), bins=50, label='TSLA')
df_gm['returns'].hist(bins=50, label='GM')
df_ford['returns'].hist(bins=50, label='Ford')
plt.legend()
plt.show()

# %% [markdown]
# ** Try also plotting a KDE instead of histograms for another view point. Which stock has the widest plot? **

# %%
import plotly.figure_factory as ff
data = [df_tesla['returns'].dropna(), df_gm['returns'].dropna(), df_ford['returns'].dropna()]
labels = ['TSLA', 'GM', 'Ford']
fig = ff.create_distplot(data, labels)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="16d05b6e-2e34-4f2b-8773-41b6715e7c25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16d05b6e-2e34-4f2b-8773-41b6715e7c25")) {                    Plotly.newPlot(                        "16d05b6e-2e34-4f2b-8773-41b6715e7c25",                        [{"autobinx": false, "histnorm": "probability density", "legendgroup": "TSLA", "marker": {"color": "rgb(31, 119, 180)"}, "name": "TSLA", "opacity": 0.7, "type": "histogram", "x": [-0.013176638176638056, -0.021291952363767574, -0.007743362831858391, 0.01263470828688229, 0.013577981651376136, 0.02208544532947143, 0.000708466170740385, -0.1932743362831859, 0.1671785870996052, 0.007894736842105177, -0.0018649757553150792, -0.005979073243647215, 0.006390977443609058, 0.024280911468061328, 0.02005835156819824, 0.03468001430103684, 0.013476157567380742, 0.008182748039549992, -0.01690902942171124, 0.01754385964912264, 0.022650439486139318, 0.02975206611570247, 0.020866773675762618, -0.0062893081761006275, 0.0104430379746836, 0.020357031005324044, -0.04542664211172487, 0.012540192926044913, 0.053350269926961014, 0.012963521254145238, 0.0172619047619047, 0.023112931538911585, -0.01344009150700598, -0.008115942028985579, 0.00905902980713047, -0.022589052997393555, -0.003851851851851884, 0.005651397977394446, -0.011830819284235572, 0.02993115833582749, -0.01075268817204289, -0.007931844888366513, -0.019543973941368198, 0.000302023557837483, -0.0015096618357487435, 0.050498941638947636, 0.03655728267127212, 0.0022216051096919376, -0.022166805209199336, -0.00821762538962878, 0.00914285714285712, -0.00962627406568528, -0.0005717552887363198, 0.005434782608695565, -0.02133712660028453, -0.009302325581395321, 0.09741784037558676, 0.01443850267379676, -0.0023721665788085655, -0.013738441215323749, -0.002410929547280949, -0.01772287862513433, 0.03909240021869875, -0.07918968692449346, -0.014857142857142902, -0.038573085846867694, -0.020814479638008976, 0.019408502772643388, 0.010577213659715756, 0.0044856459330144816, -0.03989282524560889, -0.00031007751937983663, 0.013027295285359619, 0.015309246785058184, 0.0, -0.03679131483715303, -0.0037570444583594487, 0.03425518541797601, 0.017623822546338763, -0.004478948939982019, -0.006298740251949653, 0.01961968004829462, 0.00473653049141487, -0.04360636417206831, -0.019408502772643277, 0.020106817467797633, -0.07021866338158289, -0.004306061609804623, 0.09647371922821035, -0.021541262135922334, -0.06790697674418611, -0.020958083832335328, -0.00849473326537542, -0.020904729266620903, -0.035351767588379435, 0.04390420899854863, 0.07021202641640589, 0.00746995777849957, -0.022566086395873652, -0.016820580474934066, 0.06306608520630674, -0.04039129062795843, -0.029924366984544593, -0.045762711864406835, -0.009591474245115417, 0.0010760401721665591, 0.04693658187029737, -0.009924709103353857, 0.03975112340131348, -0.031914893617021156, 0.018543956043955978, 0.0037086985839513975, -0.012764528048370805, 0.01769309288873755, 0.06452691407556, 0.007851758793969932, 0.05266438142723584, -0.047069271758437004, 0.04954954954954949, -0.019979280745893058, -0.04530353367562667, 0.011072445428661926, -0.017209011264080143, -0.00382043935052534, -0.02844359220198145, 0.008552631578947478, 0.018590998043052753, -0.007684918347742653, 0.016134236850597006, -0.006986344871387717, 0.007675087943716186, 0.03776578863852742, 0.04740061162079501, 0.04992700729927013, -0.07258064516129026, -0.0359820089955023, 0.0037325038880249295, -0.014874496436318663, -0.03554576910978291, -0.026744944553163785, -0.029825737265415597, -0.02832469775474955, 0.04905794525417706, -0.0731955269400203, 0.00255941499085921, -0.04266958424507661, -0.005714285714285672, 0.04482758620689653, 0.036670333700036 ...

# %%
df_tesla['returns'].plot.kde(figsize=(18,6), label='TSLA')
df_gm['returns'].plot.kde(label='GM')
df_ford['returns'].plot.kde(label='Ford')
plt.legend()
plt.show()

# %% [markdown]
# ** Try also creating some box plots comparing the returns. **

# %%
# Code here
# using plotly
df = pd.concat((df_tesla['returns'], df_gm['returns'], df_ford['returns']), axis=1)
df.columns = ['TSLA', 'GM', 'Ford']
fig = px.violin(df, y=df.columns, box=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="eec22dc8-bee0-4e66-bc3e-b92de5b1434c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eec22dc8-bee0-4e66-bc3e-b92de5b1434c")) {                    Plotly.newPlot(                        "eec22dc8-bee0-4e66-bc3e-b92de5b1434c",                        [{"alignmentgroup": "True", "box": {"visible": true}, "hovertemplate": "variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "scalegroup": "True", "showlegend": false, "type": "violin", "x": ["TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", "TSLA", ...

# %% [markdown]
# ## Comparing Daily Returns between Stocks
#
# ** Create a scatter matrix plot to see the correlation between each of the stocks daily returns. This helps answer the questions of how related the car companies are. Is Tesla begin treated more as a technology company rather than a car company by the market?**

# %%
df = pd.concat((df_tesla['returns'], df_ford['returns'], df_gm['returns']), axis=1)
df.columns = ['TSLA', 'FORD', 'GM']
fig = px.scatter_matrix(df, dimensions=df.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="1d0d4df3-1004-464b-a160-ca061aeb4fa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d0d4df3-1004-464b-a160-ca061aeb4fa6")) {                    Plotly.newPlot(                        "1d0d4df3-1004-464b-a160-ca061aeb4fa6",                        [{"dimensions": [{"axis": {"matches": true}, "label": "TSLA", "values": [null, -0.013176638176638056, -0.021291952363767574, -0.007743362831858391, 0.01263470828688229, 0.013577981651376136, 0.02208544532947143, 0.000708466170740385, -0.1932743362831859, 0.1671785870996052, 0.007894736842105177, -0.0018649757553150792, -0.005979073243647215, 0.006390977443609058, 0.024280911468061328, 0.02005835156819824, 0.03468001430103684, 0.013476157567380742, 0.008182748039549992, -0.01690902942171124, 0.01754385964912264, 0.022650439486139318, 0.02975206611570247, 0.020866773675762618, -0.0062893081761006275, 0.0104430379746836, 0.020357031005324044, -0.04542664211172487, 0.012540192926044913, 0.053350269926961014, 0.012963521254145238, 0.0172619047619047, 0.023112931538911585, -0.01344009150700598, -0.008115942028985579, 0.00905902980713047, -0.022589
# Great! Now we can see which stock was the most wide ranging in daily returns (you should have realized it was Tesla, our original stock price plot should have also made that obvious).
#
# With daily cumulative returns, the question we are trying to answer is the following, if I invested $1 in the company at the beginning of the time series, how much would is be worth today? This is different than just the stock price at the current day, because it will take into account the daily returns. Keep in mind, our simple calculation here won't take into account stocks that give back a dividend. Let's look at some simple examples:

# %% [markdown]
# Lets us say there is a stock 'ABC' that is being actively traded on an exchange. ABC has the following prices corresponding to the dates given

# %% [markdown]
#     Date                        Price
#     01/01/2018                   10
#     01/02/2018                   15
#     01/03/2018                   20
#     01/04/2018                   25

# %% [markdown]
# **Daily Return** : Daily return is the profit/loss made by the stock compared to the previous day. (This is what ew just calculated above). A value above one indicates profit, similarly a value below one indicates loss. It is also expressed in percentage to convey the information better. (When expressed as percentage, if the value is above 0, the stock had give you profit else loss). So for the above example the daily returns would be

# %% [markdown]
#     Date                         Daily Return                  %Daily Return
#     01/01/2018                 10/10 =  1                          -
#     01/02/2018                 15/10 =  3/2                       50%
#     01/03/2018                 20/15 =  4/3                       33%
#     01/04/2018                 25/20 =  5/4                       20%

# %% [markdown]
# **Cumulative Return**: While daily returns are useful, it doesn't give the investor a immediate insight into the gains he had made till date, especially if the stock is very volatile. Cumulative return is computed relative to the day investment is made.  If cumulative return is above one, you are making profits else you are in loss. So for the above example cumulative gains are as follows

# %% [markdown]
#     Date                       Cumulative Return         %Cumulative Return
#     01/01/2018                  10/10 =  1                         100 %
#     01/02/2018                  15/10 =  3/2                       150 %
#     01/03/2018                  20/10 =  2                         200 %
#     01/04/2018                  25/10 =  5/2                       250 %

# %% [markdown]
# The formula for a cumulative daily return is:
#
# $ i_i = (1+r_t) * i_{t-1} $
#
# Here we can see we are just multiplying our previous investment at i at t-1 by 1+our percent returns. Pandas makes this very simple to calculate with its cumprod() method. Using something in the following manner:
#
#     df[daily_cumulative_return] = ( 1 + df[pct_daily_return] ).cumprod()

# %% [markdown]
# ** Create a cumulative daily return column for each car company's dataframe.**

# %%
df_tesla['Cumulative Return'] = (df_tesla['returns'] + 1).cumprod()
df_tesla.head()
# Out:
#              Open   High    Low  Close     Volume   returns  Cumulative Return
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928100.0       NaN                NaN
# 2012-01-04  28.21  28.67  27.50  27.71   630100.0 -0.013177           0.986823
# 2012-01-05  27.76  27.93  26.85  27.12  1005500.0 -0.021292           0.965812
# 2012-01-06  27.20  27.79  26.41  26.91   986300.0 -0.007743           0.958333
# 2012-01-09  27.00  27.49  26.12  27.25   897000.0  0.012635           0.970442

# %%
# Out:
#              Open   High    Low  Close   Volume  Total Traded   returns  \
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928052   26857824.88       NaN
# 2012-01-04  28.21  28.67  27.50  27.71   630036   17773315.56 -0.013177
# 2012-01-05  27.76  27.93  26.85  27.12  1005432   27910792.32 -0.021292
# 2012-01-06  27.20  27.79  26.41  26.89   687081   18688603.20 -0.008481
# 2012-01-09  27.00  27.49  26.12  27.25   896951   24217677.00  0.013388
#
#             Cumulative Return
# Date
# 2012-01-03                NaN
# 2012-01-04           0.986823
# 2012-01-05           0.965812
# 2012-01-06           0.957621
# 2012-01-09           0.970442

# %%
df_gm['Cumulative Return'] = (df_gm['returns'] + 1).cumprod()
df_gm.head()
# Out:
#              Open   High    Low  Close      Volume   returns  Cumulative Return
# Date
# 2012-01-03  20.83  21.18  20.75  21.05   9321300.0       NaN                NaN
# 2012-01-04  21.05  21.37  20.75  21.15   7856700.0  0.004751           1.004751
# 2012-01-05  21.10  22.29  20.96  22.17  17880600.0  0.048227           1.053207
# 2012-01-06  22.26  23.03  22.24  22.92  18234500.0  0.033829           1.088836
# 2012-01-09  23.20  23.43  22.70  22.84  12084500.0 -0.003490           1.085036

# %%
df_ford['Cumulative Return'] = (df_ford['returns'] + 1).cumprod()
df_ford.head()
# Out:
#              Open   High    Low  Close      Volume   returns  Cumulative Return
# Date
# 2012-01-03  11.00  11.25  10.99  11.13  45709900.0       NaN                NaN
# 2012-01-04  11.15  11.53  11.07  11.30  79725200.0  0.015274           1.015274
# 2012-01-05  11.33  11.63  11.24  11.59  67877500.0  0.025664           1.041330
# 2012-01-06  11.74  11.80  11.52  11.71  59840700.0  0.010354           1.052111
# 2012-01-09  11.83  11.95  11.70  11.80  53981500.0  0.007686           1.060198

# %% [markdown]
# ** Now plot the Cumulative Return columns against the time series index. Which stock showed the highest return for a $1 invested? Which showed the lowest?**

# %%
# Code Here
# using plotly
df = pd.concat((df_tesla['Cumulative Return'], df_ford['Cumulative Return'], df_gm['Cumulative Return']), axis=1)
df.columns = ['TSLA', 'FORD', 'GM']
fig = px.line(df, x=df.index , y=df.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="5a98454a-0fec-4b6c-a01f-22384736381d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a98454a-0fec-4b6c-a01f-22384736381d")) {                    Plotly.newPlot(                        "5a98454a-0fec-4b6c-a01f-22384736381d",                        [{"hovertemplate": "variable=TSLA<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "TSLA", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "TSLA", "showlegend": true, "type": "scattergl", "x": ["2012-01-03T00:00:00", "2012-01-04T00:00:00", "2012-01-05T00:00:00", "2012-01-06T00:00:00", "2012-01-09T00:00:00", "2012-01-10T00:00:00", "2012-01-11T00:00:00", "2012-01-12T00:00:00", "2012-01-13T00:00:00", "2012-01-17T00:00:00", "2012-01-18T00:00:00", "2012-01-19T00:00:00", "2012-01-20T00:00:00", "2012-01-23T00:00:00", "2012-01-24T00:00:00", "2012-01-25T00:00:00", "2012-01-26T00:00:00", "2012-01-27T00:00:00", "2012-01-30T00:00:00", "2012-01-31T00:00:00", "2012-02-01T00:00:00", "2012-02-02T00:00:00", "2012-02-03T00:00:00", "2012-02-06T00:00:00", "2012-02-07T00:00:00", "2012-02-08T00:00:00", "2012-02-09T00:00:00", "2012-02-10T00:00:00", "2012-02-13T00:00:00", "2012-02-14T00:00:00", "2012-02-15T00:00:00", "2012-02-16T00:00:00", "2012-02-17T00:00:00", "2012-02-21T00:00:00", "2012-02-22T00:00:00", "2012-02-23T00:00:00", "2012-02-24T00:00:00", "2012-02-27T00:00:00", "2012-02-28T00:00:00", "2012-02-29T00:00:00", "2012-03-01T00:00:00", "2012-03-02T00:00:00", "2012-03-05T00:00:00", "2012-03-06T00:00:00", "2012-03-07T00:00:00", "2012-03-